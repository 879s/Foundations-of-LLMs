# %% [markdown]
# <h1>Chapter 3 - Looking Inside Transformer LLMs</h1>
# <i>An extensive look into the transformer architecture of generative LLMs</i>
#
# <a href="https://www.amazon.com/Hands-Large-Language-Models-Understanding/dp/1098150961"><img src="https://img.shields.io/badge/Buy%20the%20Book!-grey?logo=amazon"></a>
# <a href="https://www.oreilly.com/library/view/hands-on-large-language/9781098150952/"><img src="https://img.shields.io/badge/O'Reilly-white.svg?logo=..."></a>
# <a href="https://github.com/HandsOnLLM/Hands-On-Large-Language-Models"><img src="https://img.shields.io/badge/GitHub%20Repository-black?logo=github"></a>
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/HandsOnLLM/Hands-On-Large-Language-Models/blob/main/chapter03/Chapter%203%20-%20Looking%20Inside%20LLMs.ipynb)
#
# ---
#
# This notebook is for Chapter 3 of the [Hands-On Large Language Models](https://www.amazon.com/Hands-Large-Language-Models-Understanding/dp/1098150961) book by [Jay Alammar](https://www.linkedin.com/in/jalammar) and [Maarten Grootendorst](https://www.linkedin.com/in/mgrootendorst/).
#
# ---
#
# <a href="https://www.amazon.com/Hands-Large-Language-Models-Understanding/dp/1098150961">
# <img src="https://raw.githubusercontent.com/HandsOnLLM/Hands-On-Large-Language-Models/main/images/book_cover.png" width="350"/></a>

# %% [markdown]
# ### [OPTIONAL] - Installing Packages on <img src="https://colab.google/static/images/icons/colab.png" width=100>
#
# If you are viewing this notebook on Google Colab (or any other cloud vendor), you need to **uncomment and run** the following codeblock to install the dependencies for this chapter:
#
# ---
#
# 💡 **NOTE**: We will want to use a GPU to run the examples in this notebook. In Google Colab, go to
# **Runtime > Change runtime type > Hardware accelerator > GPU > GPU type > T4**.
#
# ---

# %%
# %%capture
# !pip install transformers>=4.41.2 accelerate>=0.31.0

# %% [markdown]
# # Loading the LLM

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")

model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct",
    device_map="cuda",
    torch_dtype="auto",
    trust_remote_code=True,
)

# Create a pipeline
generator = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    return_full_text=False,
    max_new_tokens=50,
    do_sample=False,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/3.44k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.94M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/599 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# configuration_phi3.py:   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4k-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_phi3.py:   0%|          | 0.00/73.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4k-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.0a67737cc96d2554230f90338b163bc6380a2a85.modeling_phi3:`flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.0a67737cc96d2554230f90338b163bc6380a2a85.modeling_phi3:Current `flash-attention` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# model.safetensors.index.json:   0%|          | 0.00/16.5k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/2.67G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Device set to use cuda

# %% [markdown]
# # The Inputs and Outputs of a Trained Transformer LLM

# %%
prompt = "Write an email apologizing to Sarah for the tragic gardening mishap. Explain how it happened."

output = generator(prompt)

print(output[0]['generated_text'])
# Out:
# The `seen_tokens` attribute is deprecated and will be removed in v4.41. Use the `cache_position` model input instead.
# `get_max_cache()` is deprecated for all Cache classes. Use `get_max_cache_shape()` instead. Calling `get_max_cache()` will raise error from v4.48
# WARNING:transformers_modules.microsoft.Phi-3-mini-4k-instruct.0a67737cc96d2554230f90338b163bc6380a2a85.modeling_phi3:You are not running the flash-attention implementation, expect numerical differences.
#  Mention the steps you're taking to prevent it in the future.
#
# Dear Sarah,
#
# I hope this message finds you well. I am writing to express my deepest apologies for the unfortunate incident that occurred in

# %%
print(model)
# Out:
# Phi3ForCausalLM(
#   (model): Phi3Model(
#     (embed_tokens): Embedding(32064, 3072, padding_idx=32000)
#     (embed_dropout): Dropout(p=0.0, inplace=False)
#     (layers): ModuleList(
#       (0-31): 32 x Phi3DecoderLayer(
#         (self_attn): Phi3Attention(
#           (o_proj): Linear(in_features=3072, out_features=3072, bias=False)
#           (qkv_proj): Linear(in_features=3072, out_features=9216, bias=False)
#           (rotary_emb): Phi3RotaryEmbedding()
#         )
#         (mlp): Phi3MLP(
#           (gate_up_proj): Linear(in_features=3072, out_features=16384, bias=False)
#           (down_proj): Linear(in_features=8192, out_features=3072, bias=False)
#           (activation_fn): SiLU()
#         )
#         (input_layernorm): Phi3RMSNorm()
#         (resid_attn_dropout): Dropout(p=0.0, inplace=False)
#         (resid_mlp_dropout): Dropout(p=0.0, inplace=False)
#         (post_attention_layernorm): Phi3RMSNorm()
#       )
#     )
#     (norm): Phi3RMSNorm()
#   )
#   (lm_head): Linear(in_features=3072, out_features=32064, bias=False)
# )

# %%
messages = [
    {"role":"user","content":prompt},
]
text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)
print(text)
# Out:
# <|user|>
# Write an email apologizing to Sarah for the tragic gardening mishap. Explain how it happened.<|end|>
# <|assistant|>

# %%
generator(text)[0]["generated_text"]
# Out:
# ' Subject: Sincere Apologies for the Gardening Mishap\n\n\nDear Sarah,\n\n\nI hope this message finds you well. I am writing to express my deepest apologies for the unfortunate incident that'

# %% [markdown]
# # Choosing a single token from the probability distribution (sampling / decoding)

# %%
prompt = "The capital of the United Kingdom is"

# Tokenize the input prompt
input_ids = tokenizer(prompt, return_tensors="pt").input_ids

# Tokenize the input prompt
input_ids = input_ids.to("cuda")

# Get the output of the model before the lm_head
model_output = model.model(input_ids)

# Get the output of the lm_head
lm_head_output = model.lm_head(model_output[0])

# %%
token_id = lm_head_output[0,-1].argmax(-1)
tokenizer.decode(token_id)
# Out:
# 'London'

# %%
model_output[0].shape
# Out:
# torch.Size([1, 7, 3072])

# %%
lm_head_output.shape
# Out:
# torch.Size([1, 7, 32064])

# %%
print(token_id)
# Out:
# tensor(4517, device='cuda:0')

# %%
output = model.generate(input_ids)
tokenizer.decode(output[0])
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# 'The capital of the United Kingdom is London.\n\n\nLondon is the capital city of the United Kingdom, which is a so'

# %% [markdown]
# # Speeding up generation by caching keys and values

# %%
prompt = "Write a very long email apologizing to Sarah for the tragic gardening mishap. Explain how it happened."

# Tokenize the input prompt
input_ids = tokenizer(prompt, return_tensors="pt").input_ids
input_ids = input_ids.to("cuda")

# %%
# %%timeit -n 1
# Generate the text
generation_output1 = model.generate(
  input_ids=input_ids,
  max_new_tokens=100,
  use_cache=True
)
# Out:
# 4.7 s ± 266 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit -n 1
# Generate the text
generation_output2 = model.generate(
  input_ids=input_ids,
  max_new_tokens=100,
  use_cache=False
)
# Out:
# 32.3 s ± 79 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
generation_output1 = model.generate(
  input_ids=input_ids,
  max_new_tokens=1000,
  use_cache=True
)

# %%
decoded_output = tokenizer.decode(generation_output1[0], skip_special_tokens=False)

# 打印生成的文本
print(decoded_output)
# Out:
# Write a very long email apologizing to Sarah for the tragic gardening mishap. Explain how it happened. Mention the emotional impact it had on her. Discuss the steps you will take to make amends. Include a heartfelt apology.
#
# Dear Sarah,
#
# I hope this message finds you in good health and spirits, despite the unfortunate events that have unfolded recently. I am writing to you with a heavy heart, as I am deeply sorry for the tragic gardening mishap that occurred in your beautiful garden.
#
# It all started when I decided to help you with your garden, as I have always admired your green thumb and the way you nurture your plants. I thought it would be a wonderful opportunity to spend some quality time together and share my love for gardening. However, things took an unexpected turn, and I am truly sorry for the damage that was caused.
#
# As we were working together, I accidentally knocked over a large pot of your prized roses. The pot shattered, and the beautiful flowers were scattered across the ground. I was mortified by the sight and immediately felt a wave of guilt wash over me. I know how much those roses meant to you, and I can only imagine the emotional impact this incident has had on you.
#
# I understand that the loss of your beloved roses is not just a physical one but also an emotional one. They were not just plants; they were a symbol of your hard work, dedication, and love for gardening. I can only imagine the sadness and disappointment you must be feeling right now.
#
# Please know that I am truly sorry for what happened, and I am committed to making amends. I have already contacted a professional gardener to help restore your garden to its former glory. They will work diligently to replant the roses and ensure that your garden is as beautiful as it once was. Additionally, I have offered to cover all the costs associated with the restoration process, as I believe it is only fair to compensate you for the loss.
#
# I also want to assure you that I will be more careful and attentive in the future when working in your garden. I understand the importance of respecting your space and the value of your plants, and I will do everything in my power to prevent such an incident from happening again.
#
# Once again, I am deeply sorry for the tragic gardening mishap and the emotional toll it has taken on you. I hope that you can find it in your heart to forgive me, as I am truly remorseful for my actions. I value our friendship and the bond we share, and I am committed to making things right.
#
# Please let me know if there is anything else I can do to help you through this difficult time. I am here for you, and I will do whatever it takes to make amends and restore your trust in me.
#
# With heartfelt apologies,
#
# [Your Name]
#
# References:
#
# 1. "Gardening Mishaps and How to Avoid Them." Gardening Know How. https://www.gardeningknowhow.com/garden-how-to/gardening-mishaps.htm
#
# 2. "The Emotional Impact of Gardening Loss." Horticulture Week. https://www.hortweek.com/the-emotional-impact-of-gardening-loss/
#
# 3. "How to Restore a Damaged Garden." Gardening Know How. https://www.gardeningknowhow.com/garden-how-to/garden-restoration.htm
#
# 4. "The Importance of Apologizing in Relationships." Psychology Today. https://www.psychologytoday.com/us/blog/the-relationship-cure/201301/the-importance-apologizing-relationships
#
# 5. "The Psychology of Apologies." Psychology Today. https://www.psychologytoday.com/us/blog/the-relationship-cure/201301/the-psychology-apologies
#
# 6. "The Emotional Impact of Gardening Loss." Horticulture Week. https://www.hortweek.com/the-emotional-impact-of-gardening-loss/
#
# 7. "How to Restore a Damaged Garden." Gardening Know How. https://www.gardeningknowhow.com/garden-restoration.htm
#
# 8. "The Importance of Apologizing in Relationships." Psychology Today

# %%
generation_output2 = model.generate(
  input_ids=input_ids,
  max_new_tokens=1000,
  use_cache=False
)

# %%
decoded_output = tokenizer.decode(generation_output2[0], skip_special_tokens=True)

# 打印生成的文本
print(decoded_output)
